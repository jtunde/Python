# %% [markdown]
# <a href="https://colab.research.google.com/github/jtunde/Python/blob/main/cn2%20NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('drive/MyDrive/data.csv',index_col='TIME',parse_dates=True)
print(df.head())
# Out:
#                RON
# TIME
# 2021-01-01  4.9493
# 2021-01-02  4.9493
# 2021-01-03  4.9493
# 2021-01-04  4.8713
# 2021-01-05  4.8721

# %%
df.plot(figsize=(12,6))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(df['RON'])
results.plot();

# %%
len(df)
# Out:
# 337

# %%
train = df.iloc[:274]
test = df.iloc[274:]

# %%
plt.rcParams['figure.figsize'] = (12, 6)
plt.plot(train['RON'], color = "blue")
plt.plot(test['RON'], color = "red")
plt.ylabel('RON')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df.head(),df.tail()
# Out:
# (               RON
#  TIME
#  2021-01-01  4.9493
#  2021-01-02  4.9493
#  2021-01-03  4.9493
#  2021-01-04  4.8713
#  2021-01-05  4.8721,                RON
#  TIME
#  2021-11-29  4.9498
#  2021-11-30  4.9510
#  2021-12-01  4.9467
#  2021-12-02  4.9488
#  2021-12-03  4.9493)

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.98132005],
#        [0.98132005],
#        [0.98132005],
#        [0.00996264],
#        [0.01992528],
#        [0.01867995],
#        [0.00871731],
#        [0.00373599],
#        [0.00373599],
#        [0.00373599]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
# define generator
n_input = 3
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.98132005 0.98132005 0.98132005]
# Predict this y:
#  [[0.00996264]]

# %%
X.shape
# Out:
# (1, 3, 1)

# %%
# We do the same thing, but now instead for 12 months
n_input = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 100)               40800
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=10)
# Out:
# Epoch 1/10
# 262/262 [==============================] - 3s 10ms/step - loss: 0.0043
# Epoch 2/10
# 262/262 [==============================] - 2s 7ms/step - loss: 0.0036
# Epoch 3/10
# 262/262 [==============================] - 2s 8ms/step - loss: 0.0033
# Epoch 4/10
# 262/262 [==============================] - 2s 7ms/step - loss: 0.0036
# Epoch 5/10
# 262/262 [==============================] - 2s 7ms/step - loss: 0.0030
# Epoch 6/10
# 262/262 [==============================] - 2s 7ms/step - loss: 0.0027
# Epoch 7/10
# 262/262 [==============================] - 2s 7ms/step - loss: 0.0027
# Epoch 8/10
# 262/262 [==============================] - 2s 7ms/step - loss: 0.0024
# Epoch 9/10
# 262/262 [==============================] - 2s 8ms/step - loss: 0.0026
# Epoch 10/10
# 262/262 [==============================] - 2s 8ms/step - loss: 0.0024

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-12:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# array([[0.94032574]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.95267746])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.94032574], dtype=float32),
#  array([0.93200094], dtype=float32),
#  array([0.925571], dtype=float32),
#  array([0.91889983], dtype=float32),
#  array([0.9117927], dtype=float32),
#  array([0.90509814], dtype=float32),
#  array([0.898661], dtype=float32),
#  array([0.89243144], dtype=float32),
#  array([0.8863409], dtype=float32),
#  array([0.88047606], dtype=float32),
#  array([0.8747525], dtype=float32),
#  array([0.8692135], dtype=float32),
#  array([0.86384904], dtype=float32),
#  array([0.8586494], dtype=float32),
#  array([0.85360897], dtype=float32),
#  array([0.84871835], dtype=float32),
#  array([0.84397817], dtype=float32),
#  array([0.83938384], dtype=float32),
#  array([0.8349313], dtype=float32),
#  array([0.83061713], dtype=float32),
#  array([0.8264375], dtype=float32),
#  array([0.8223886], dtype=float32),
#  array([0.81846726], dtype=float32),
#  array([0.81466955], dtype=float32),
#  array([0.8109924], dtype=float32),
#  array([0.80743235], dtype=float32),
#  array([0.803986], dtype=float32),
#  array([0.80065], dtype=float32),
#  array([0.7974219], dtype=float32),
#  array([0.79429865], dtype=float32),
#  array([0.79127675], dtype=float32),
#  array([0.7883536], dtype=float32),
#  array([0.78552604], dtype=float32),
#  array([0.78279114], dtype=float32),
#  array([0.7801461], dtype=float32),
#  array([0.7775885], dtype=float32),
#  array([0.7751154], dtype=float32),
#  array([0.7727244], dtype=float32),
#  array([0.7704125], dtype=float32),
#  array([0.76817775], dtype=float32),
#  array([0.7660177], dtype=float32),
#  array([0.76392996], dtype=float32),
#  array([0.76191187], dtype=float32),
#  array([0.7599618], dtype=float32),
#  array([0.7580772], dtype=float32),
#  array([0.75625646], dtype=float32),
#  array([0.7544971], dtype=float32),
#  array([0.75279725], dtype=float32),
#  array([0.7511551], dtype=float32),
#  array([0.7495685], dtype=float32),
#  array([0.74803615], dtype=float32),
#  array([0.7465559], dtype=float32),
#  array([0.7451262], dtype=float32),
#  array([0.74374527], dtype=float32),
#  array([0.7424114], dtype=float32),
#  array([0.74112356], dtype=float32),
#  array([0.73987967], dtype=float32),
#  array([0.7386785], dtype=float32),
#  array([0.7375187], dtype=float32),
#  array([0.73639876], dtype=float32),
#  array([0.7353145], dtype=float32),
#  array([0.7342658], dtype=float32),
#  array([0.7332524], dtype=float32)]

# %%
test.head()
# Out:
#                RON
# TIME
# 2021-10-02  4.9470
# 2021-10-03  4.9470
# 2021-10-04  4.9478
# 2021-10-05  4.9477
# 2021-10-06  4.9458

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test.plot(figsize=(14,5))

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['RON'],test['Predictions']))
print(rmse)
# Out:
# 0.014571578816228751
